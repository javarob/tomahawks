# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from random import sample

# %%
data = "wine_sales_2018.csv"
wine_sales = pd.read_csv(data)
wine_sales.head()
# Out:
#    Year  Table Wine  Dessert Wine  Sparkling Wine/Champagne  Total Wine Sales  \
# 0  2018       338.7          40.4                      27.4             406.5
# 1  2017       336.1          40.8                      26.4             403.3
# 2  2016       332.0          41.2                      24.4             397.6
# 3  2015       324.7          40.2                      21.7             386.6
# 4  2014       323.4          34.6                      19.8             377.8
#
#   Total Retail Value
# 0      $68.1 billion
# 1      $65.3 billion
# 2      $63.3 billion
# 3      $60.5 billion
# 4      $56.8 billion

# %%
df=pd.DataFrame(wine_sales)
df=df.set_index('Year')
df.head()
# Out:
#       Table Wine  Dessert Wine  Sparkling Wine/Champagne  Total Wine Sales  \
# Year
# 2018       338.7          40.4                      27.4             406.5
# 2017       336.1          40.8                      26.4             403.3
# 2016       332.0          41.2                      24.4             397.6
# 2015       324.7          40.2                      21.7             386.6
# 2014       323.4          34.6                      19.8             377.8
#
#      Total Retail Value
# Year
# 2018      $68.1 billion
# 2017      $65.3 billion
# 2016      $63.3 billion
# 2015      $60.5 billion
# 2014      $56.8 billion

# %%
print(df.iloc[0],[6])
# Out:
# Table Wine                          338.7
# Dessert Wine                         40.4
# Sparkling Wine/Champagne             27.4
# Total Wine Sales                    406.5
# Total Retail Value          $68.1 billion
# Name: 2018, dtype: object [6]

# %%
labels = ["Table Wine", "Dessert Wine", "Sparkling Wine/Champagne"]
value =[338.7,40.4,27.4]
total = [406.5]
explode = (0.1, 0,0)
colors = ["maroon", "yellow", "lightcoral", "orange" ]
plt.title("2018 U.S. Wine Sales" )
plt.pie(value, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

df
# Out:
# <img src="data:image/png;base64,..." width="639.999982048484">
#       Table Wine  Dessert Wine  Sparkling Wine/Champagne  Total Wine Sales  \
# Year
# 2018       338.7          40.4                      27.4             406.5
# 2017       336.1          40.8                      26.4             403.3
# 2016       332.0          41.2                      24.4             397.6
# 2015       324.7          40.2                      21.7             386.6
# 2014       323.4          34.6                      19.8             377.8
# 2013       326.2          31.6                      18.4             376.2
# 2012       319.1          30.3                      17.5             366.9
# 2011       307.6          31.4                      17.2             356.2
# 2010       291.4          28.9                      15.3             335.6
# 2009       287.7          27.2                      13.9             328.8
# 2008       273.1          27.7                      13.5             314.3
# 2007       273.3          26.7                      13.8             313.8
# 2006       259.4          24.3                      13.6             297.3
# 2005       253.5          22.5                      13.1             289.1
# 2004       245.3          20.3                      13.2             278.8
# 2003       237.0          17.6                      12.0             266.6
# 2002       222.6          15.9                      11.5             250.0
#
#      Total Retail Value
# Year
# 2018      $68.1 billion
# 2017      $65.3 billion
# 2016      $63.3 billion
# 2015      $60.5 billion
# 2014      $56.8 billion
# 2013      $53.4 billion
# 2012      $51.7 billion
# 2011      $50.3 billion
# 2010      $47.7 billion
# 2009      $45.6 billion
# 2008      $44.7 billion
# 2007      $43.7 billion
# 2006      $42.2 billion
# 2005      $39.5 billion
# 2004      $36.2 billion
# 2003      $34.0 billion
# 2002      $33.0 billion

# %%
plt.savefig('wine_sales_pie2018.png')
