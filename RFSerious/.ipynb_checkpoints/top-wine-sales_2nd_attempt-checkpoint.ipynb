# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.colors as pltc
all_colors = [k for k,v in pltc.cnames.items()]
import pandas as pd
import numpy as np
from random import sample

# %%
top_wine_types_csv = "top_wine_variety_by_sales_volume.csv"
top_wine_types = pd.read_csv(top_wine_types_csv, encoding="latin")
top_wine_types.head()
# Out:
#    Rank             Variety  Sales Percentage by Volume
# 0     1          Chardonnay                        0.19
# 1     2  Cabernet Sauvignon                        0.15
# 2     3          Red Blends                        0.11
# 3     4   Pinot Grigio/Gris                        0.10
# 4     5              Merlot                        0.06

# %%
df=pd.DataFrame(top_wine_types)
df=df.set_index('Rank')
df
# Out:
#                     Variety  Sales Percentage by Volume
# Rank
# 1                Chardonnay                        0.19
# 2        Cabernet Sauvignon                        0.15
# 3                Red Blends                        0.11
# 4         Pinot Grigio/Gris                        0.10
# 5                    Merlot                        0.06
# 6            Moscato/Muscat                        0.06
# 7                Pinot Noir                        0.05
# 8           Sauvignon Blanc                        0.05
# 9     White Zinfandel/Blush                        0.04
# 10                    Rosay                        0.03

# %%
x_axis = np.arange(0,len(df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

#plt.xlim(-0.75, len(q2_csv_df)-0.25)
#plt.ylim(ymax=20, ymin=1)

plt.figure(figsize=(15,5))
plt.bar(x_axis,df['Sales Percentage by Volume'], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, df['Variety'], rotation='vertical')

plt.title("Top Wine Varieties by Volume Sales Percentage - U.S.")  
plt.xlabel("Wine Varities")
plt.ylabel("Percentage of 2018 Sales")
# Out:
# <img src="data:image/png;base64,..." width="1333.3333686546052">
# Text(0, 0.5, 'Percentage of 2018 Sales')

# %%
#plt.tops_chart1_bar.to_csv('tops_chart1_bar.png')

# %%
wine_percent = ['Sales Percentage by Volume']
wvariety = ['Variety']

theme = plt.get_cmap('copper')
#r = random.randint(0,255)
#g = random.randint(0,255)
#b = random.randint(0,255)
#rgb = [r,g,b]
color = [theme]


from cycler import cycler
df.set_prop_cycle(cycler("color", [theme(1. * i / len(wine_percent))
                             for i in range(len(wine_percent))])

_,_ = df.pie(wvariety, startangle=90, radius=1800)
 
df.axis('equal')
 
total = sum(wvariety)



plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100)
            for l, s in zip(wvariety, wine_percent)],
    prop={'size': 11},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig1.transFigure
)
 
plt.show()
# Out:
#   File "<ipython-input-57-5110cfac119a>", line 16
#     _,_ = df.pie(wvariety, startangle=90, radius=1800)
#     ^
# SyntaxError: invalid syntax

# %%
wine_percent = ['Sales Percentage by Volume']
wvariety = ['Variety']


explode = ((wine_percent == max(wine_percent)).astype(int) / 20).tolist()

for val in range(2):
    colors = sample(all_colors, len(wine_percent))
    plt.figure(figsize=(8,8))
    plt.pie(wine_percent, labels=wvariety, autopct='%1.1f%%', 
            shadow=True, explode=explode, colors=colors)
    plt.legend(labels, loc=(1.05, 0.7), shadow=True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-bf8ed5c29abb> in <module>
#       3
#       4
# ----> 5 explode = ((wine_percent == max(wine_percent)) / 20).tolist()
#       6
#       7 for val in range(2):
#
# AttributeError: 'float' object has no attribute 'tolist'

# %%
tops_chart2_pie=
