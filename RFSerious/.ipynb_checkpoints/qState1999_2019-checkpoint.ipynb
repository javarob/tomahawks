# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
plt.rcdefaults()

# %%
q2_csv = "q2-bonded-wine-producers-by-state-1999-june-2019.csv"
q2_csv_df = pd.read_csv(q2_csv, encoding="latin")
q2_csv_df.fillna("",inplace=True)
q2_csv_df.tail()
# Out:
#    State 1999 2000 2001 2002 2003 2004 2005 2006 2007  ... 2011 2012 2013  \
# 46    VT   10   10    8    8    8   10   10   15   17  ...   35   37   42
# 47    WA  163  182  231  268  325  376  454  527  578  ...  804  849  915
# 48    WI   20   24   26   27   29   35   40   41   48  ...   88  103  113
# 49    WV   13   15   16   16   16   17   18   19   19  ...   24   26   29
# 50    WY                                               ...    *    5    6
#
#    2014 2015  2016  2017  2018 Through 3/31/2019  Through 6/30/2019
# 46   43   47    51    68    71                76                 79
# 47  989  985  1019  1091  1171              1202               1218
# 48  131  138   139   149   168               182                186
# 49   30   30    32    37    37                39                 39
# 50    7    8     8     8     9                10                 10
#
# [5 rows x 23 columns]

# %%
producers_2018 = q2_csv_df['2018']
producers_2018.head()
# Out:
# 0      10
# 1      42
# 2      36
# 3     111
# 4    5217
# Name: 2018, dtype: int64

# %%
prod_states = q2_csv_df['State']
prod_states.head()
# Out:
# 0    AK
# 1    AL
# 2    AR
# 3    AZ
# 4    CA
# Name: State, dtype: object

# %%
producers_2018_df=pd.concat([prod_states, producers_2018], axis=1)
producers_2018_df.head()
# Out:
#   State  2018
# 0    AK    10
# 1    AL    42
# 2    AR    36
# 3    AZ   111
# 4    CA  5217

# %%
lgprodstate = q2_csv_df.iloc(max("State").value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-7374498681bb> in <module>
# ----> 1 lgprodstate = q2_csv_df.iloc(max("State").value)
#
# AttributeError: 'str' object has no attribute 'value'

# %%
#state_and_2018 = q2_csv_df[['State', "2018"]]
#state_and_2018 = state_and_2018.set_index("State")
#state_and_2018.head()

#q2_csv_df.plot(kind='bar', figsize=(20,8))
#plt.title("Wine Producers by State - U.S.")  
#plt.xlabel("States")
#plt.ylabel("Number of Producers")

#plt.show()
#plt.tight_layout()

# %%
x_axis = np.arange(0,len(q2_csv_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)


plt.title("Wine Producers by State - U.S.")  
#plt.xlabel("States")
plt.ylabel("Number of Producers")

#plt.xlim(-0.75, len(q2_csv_df)-0.25)
#plt.ylim(ymax=500, ymin=1)

plt.figure(figsize=(20,3))
plt.bar(x_axis,producers_2018_df['2018'], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, producers_2018_df['State'], rotation='vertical')
# Out:
# <img src="data:image/png;base64,..." width="639.999982048484">
# <img src="data:image/png;base64,..." width="1999.9999439015123">
# ([<matplotlib.axis.XTick at 0x184a92de748>,
#   <matplotlib.axis.XTick at 0x184a92de080>,
#   <matplotlib.axis.XTick at 0x184a92d4d68>,
#   <matplotlib.axis.XTick at 0x184a937f358>,
#   <matplotlib.axis.XTick at 0x184a937f828>,
#   <matplotlib.axis.XTick at 0x184a937fcf8>,
#   <matplotlib.axis.XTick at 0x184a9388208>,
#   <matplotlib.axis.XTick at 0x184a93886d8>,
#   <matplotlib.axis.XTick at 0x184a9388ba8>,
#   <matplotlib.axis.XTick at 0x184a9390128>,
#   <matplotlib.axis.XTick at 0x184a9390588>,
#   <matplotlib.axis.XTick at 0x184a9388780>,
#   <matplotlib.axis.XTick at 0x184a937f978>,
#   <matplotlib.axis.XTick at 0x184a93907b8>,
#   <matplotlib.axis.XTick at 0x184a9390eb8>,
#   <matplotlib.axis.XTick at 0x184a9399470>,
#   <matplotlib.axis.XTick at 0x184a93999e8>,
#   <matplotlib.axis.XTick at 0x184a9399f60>,
#   <matplotlib.axis.XTick at 0x184a93a0518>,
#   <matplotlib.axis.XTick at 0x184a93a0a90>,
#   <matplotlib.axis.XTick at 0x184a93a60b8>,
#   <matplotlib.axis.XTick at 0x184a93a0320>,
#   <matplotlib.axis.XTick at 0x184a9399550>,
#   <matplotlib.axis.XTick at 0x184a93a64a8>,
#   <matplotlib.axis.XTick at 0x184a93a6a58>,
#   <matplotlib.axis.XTick at 0x184a93a6ba8>,
#   <matplotlib.axis.XTick at 0x184a93ab588>,
#   <matplotlib.axis.XTick at 0x184a93abb00>,
#   <matplotlib.axis.XTick at 0x184a93b5128>,
#   <matplotlib.axis.XTick at 0x184a93b5630>,
#   <matplotlib.axis.XTick at 0x184a93b5ba8>,
#   <matplotlib.axis.XTick at 0x184a93ab908>,
#   <matplotlib.axis.XTick at 0x184a93a68d0>,
#   <matplotlib.axis.XTick at 0x184a93b5a20>,
#   <matplotlib.axis.XTick at 0x184a93bc358>,
#   <matplotlib.axis.XTick at 0x184a93bc8d0>,
#   <matplotlib.axis.XTick at 0x184a93bce48>,
#   <matplotlib.axis.XTick at 0x184a93c1400>,
#   <matplotlib.axis.XTick at 0x184a93c1978>,
#   <matplotlib.axis.XTick at 0x184a93c1ef0>,
#   <matplotlib.axis.XTick at 0x184a93c17f0>,
#   <matplotlib.axis.XTick at 0x184a93bc828>,
#   <matplotlib.axis.XTick at 0x184a93b5588>,
#   <matplotlib.axis.XTick at 0x184a93c99b0>,
#   <matplotlib.axis.XTick at 0x184a93c9f28>,
#   <matplotlib.axis.XTick at 0x184a93d04e0>,
#   <matplotlib.axis.XTick at 0x184a93d0a58>,
#   <matplotlib.axis.XTick at 0x184a93d0ba8>,
#   <matplotlib.axis.XTick at 0x184a93d9588>,
#   <matplotlib.axis.XTick at 0x184a93d9b00>,
#   <matplotlib.axis.XTick at 0x184a93d9be0>],
#  <a list of 51 Text xticklabel objects>)

# %%
#plt.rcdefaults()
#fig, ax = plt.subplots()

#x_pos = np.arange(len(prod_states))
#ax.barh(x_pos, producers_2018, align='center',
        #color='blue', ecolor='black')
#ax.set_xticks(x_pos)
#ax.set_xticklabels("States")
#ax.invert_yaxis()  # labels read top-to-bottom
#ax.set_ylabel("Number of Producers")
#ax.set_title("Wine Producers by State - U.S.")

#plt.show()

# %%
plt.show()
plt.savefig('wineproducers_error_bar.png')
