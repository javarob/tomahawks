# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import pprint
import os
import datetime
from random import sample

# %% [markdown]
# #Rob's Questions - Wine Scores in Country/US States

# %%
#pull in data and get rid of non-province entries
#get rid of america as a province

winemag2 = "./csv/winemag-data-130k-rob.csv"
winemag_data2 = pd.read_csv(winemag2)
#df = df[df.line_race != 0]
winemag_data2 = winemag_data2[winemag_data2.province != 'America']

# %%
#remove unnecessary/unused columns
winemag2_df = winemag_data2.drop(columns=["Unnamed: 0","description","region_1","region_2","taster_name","taster_twitter_handle","title"])
winemag2_df.head()
# Out:
#     country                         designation  points  price  \
# 0     Italy                        Vulkà Bianco      87    NaN
# 1  Portugal                            Avidagos      87   15.0
# 2        US                                 NaN      87   14.0
# 3        US                Reserve Late Harvest      87   13.0
# 4        US  Vintner's Reserve Wild Child Block      87   65.0
#
#             province         variety               winery
# 0  Sicily & Sardinia     White Blend              Nicosia
# 1              Douro  Portuguese Red  Quinta dos Avidagos
# 2             Oregon      Pinot Gris            Rainstorm
# 3           Michigan        Riesling           St. Julian
# 4             Oregon      Pinot Noir         Sweet Cheeks

# %%
#check row counts
winemag_all_rows = winemag2_df
winemag_all_rows.count()
# Out:
# country        129813
# designation     92437
# points         129876
# price          120880
# province       129813
# variety        129875
# winery         129876
# dtype: int64

# %%
# get rid of the indexing from xls
winemag_all_rows=winemag_all_rows.reset_index(drop=True)
winemag_all_rows.head()
# Out:
#     country                         designation  points  price  \
# 0     Italy                        Vulkà Bianco      87    NaN
# 1  Portugal                            Avidagos      87   15.0
# 2        US                                 NaN      87   14.0
# 3        US                Reserve Late Harvest      87   13.0
# 4        US  Vintner's Reserve Wild Child Block      87   65.0
#
#             province         variety               winery
# 0  Sicily & Sardinia     White Blend              Nicosia
# 1              Douro  Portuguese Red  Quinta dos Avidagos
# 2             Oregon      Pinot Gris            Rainstorm
# 3           Michigan        Riesling           St. Julian
# 4             Oregon      Pinot Noir         Sweet Cheeks

# %%
# have a look at the country counts and averages
by_country_count = winemag_all_rows.groupby("country").count()
by_country_count
by_country_mean = winemag_all_rows.groupby("country").mean().reset_index() #get country to show
by_country_mean.head()
# Out:
#                   country     points      price
# 0               Argentina  86.710263  24.510117
# 1                 Armenia  87.500000  14.500000
# 2               Australia  88.580507  35.437663
# 3                 Austria  90.101345  30.762772
# 4  Bosnia and Herzegovina  86.500000  12.500000

# %%
# just in case I want to look at the data 
winemag_all_rows.to_csv("./csv/winemag_cleaned.csv")

# %%
#verify data
winemag_all_rows.shape
# Out:
# (129876, 7)

# %%
# clean up blank entries
winemag_all_cleaned = winemag_all_rows.dropna()

# %%
# Strip out US specific data
winemag_US = winemag_all_rows.loc[winemag_all_rows['country'] == "US"]
winemag_US.head()
# Out:
#    country                         designation  points  price    province  \
# 2       US                                 NaN      87   14.0      Oregon
# 3       US                Reserve Late Harvest      87   13.0    Michigan
# 4       US  Vintner's Reserve Wild Child Block      87   65.0      Oregon
# 10      US                      Mountain Cuvée      87   19.0  California
# 12      US                                 NaN      87   34.0  California
#
#                variety              winery
# 2           Pinot Gris           Rainstorm
# 3             Riesling          St. Julian
# 4           Pinot Noir        Sweet Cheeks
# 10  Cabernet Sauvignon  Kirkland Signature
# 12  Cabernet Sauvignon    Louis M. Martini

# %%
# order by state & use as index
by_US_state = winemag_US.groupby("province").mean().reset_index()
by_US_state.head()
# Out:
#       province     points      price
# 0      Arizona  84.926829  29.200000
# 1   California  88.627776  39.041048
# 2     Colorado  86.117647  32.985294
# 3  Connecticut  84.000000  15.333333
# 4       Hawaii  87.000000  28.000000

# %%
# adjust the by state values for better viewing
by_state_mean = by_US_state.sort_values(by=['points'], ascending=False)
by_state_mean["points"] = by_state_mean["points"] - 80

# %%
# adjust country values to better highlight the differences
by_country_mean = by_country_mean.sort_values(by=['points'], ascending=False)
by_country_mean["points"] = by_country_mean["points"] - 80

# %%
labels = by_country_mean["country"]
score_vals = by_country_mean["points"]
scorechange = by_country_mean["points"]

x = np.arange(len(labels))  # the label locations
#width = 0.35  # the width of the bars
width = 1  # the width of the bars

fig, ax = plt.subplots(figsize=(23,10))
#fig, ax = plt.subplots()
#rects1 = ax.bar(x - width/2, drug_vals, width)
rects1 = ax.bar(x - width/2, score_vals, width, color=['#0000FF' if row >= 10 else '#AA0000' if row < 4.5  else '#008000'  for row in scorechange])
#['yes' if v == 1 else 'no' if v == 2 else 'idle' for v in l]#800080 red='#AA0000' green='#008000' purple= '#800080'
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Average Wine Score (-80)')
ax.set_title('Average Wine Score by Country')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=90)
#ax.legend()
ax.grid()



def autolabel(rects, ax):
    # Get y-axis height to calculate label position from.
    (y_bottom, y_top) = ax.get_ylim()
    y_height = y_top - y_bottom

    for rect in rects:
        height = rect.get_height()
        #print(height)

        # Fraction of axis height taken up by this rectangle
        p_height = (height / y_height)
        
        if height < 0: 
            label_position =  -1   
        else:
            label_position = 1 
        #dispval = int(height)
        dispval = height
        if dispval >= 90:
            ax.text(rect.get_x() + rect.get_width()/2., label_position,
                '8%.1f' % dispval,
                 ha='center', va='bottom', color = "w")
        else:
            dispval = dispval + 80
            ax.text(rect.get_x() + rect.get_width()/2., label_position,
                '%.1f' % dispval,
                 ha='center', va='bottom', color = "w")

autolabel(rects1 ,ax)

fig.tight_layout()
fig.savefig("./out/by_country1.png")
#fig.show()
# Out:
# <img src="data:image/png;base64,..." width="2300">

# %%
labels = by_state_mean["province"]
score_vals = by_state_mean["points"]
scorechange = by_state_mean["points"]

x = np.arange(len(labels))  # the label locations
#width = 0.35  # the width of the bars
width = 1  # the width of the bars

fig, ax = plt.subplots(figsize=(20,10))
#rects1 = ax.bar(x - width/2, drug_vals, width)
rects1 = ax.bar(x - width/2, score_vals, width, color=['#0000FF' if row > 9 else '#AA0000' if row <= 3  else '#008000'  for row in scorechange])
#['yes' if v == 1 else 'no' if v == 2 else 'idle' for v in l]#800080 red='#AA0000' green='#008000' purple= '#800080'
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Average Wine Score (-80)')
ax.set_title('Average Wine Score by State')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=90)
#ax.legend()
ax.grid()



def autolabel(rects, ax):
    # Get y-axis height to calculate label position from.
    (y_bottom, y_top) = ax.get_ylim()
    y_height = y_top - y_bottom

    for rect in rects:
        height = rect.get_height()
        #print(height)

        # Fraction of axis height taken up by this rectangle
        p_height = (height / y_height)
        
        if height < 0: 
            label_position =  -1   
        else:
            label_position = 1 
        #dispval = int(height)
        dispval = height
        if dispval >= 90:
            ax.text(rect.get_x() + rect.get_width()/2., label_position,
                '8%.1f' % dispval,
                 ha='center', va='bottom', color = "w")
        else:
            dispval = dispval + 80
            ax.text(rect.get_x() + rect.get_width()/2., label_position,
                '%.1f' % dispval,
                 ha='center', va='bottom', color = "w")

autolabel(rects1 ,ax)

plt.tight_layout()
plt.savefig("./out/by_state1.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %% [markdown]
# Michael Bell

# %% [markdown]
# Question 1: Wine Variety vs. Sales Percentage by Volume (US)

# %%
# Files to load
variety_by_sales_data_to_load = "csv/top_wine_variety_by_sales_volume.csv"
winemag_data_to_load = "csv/winemag_data_v2.csv"

# Read data
variety_by_sales_data = pd.read_csv(variety_by_sales_data_to_load)
winemag_data = pd.read_csv(winemag_data_to_load)

variety_by_sales_data.head()
# Out:
#                    Variety  Sales Percentage by Volume
# 0               Chardonnay                        18.6
# 1       Cabernet Sauvignon                        14.6
# 2                Red Blend                        10.6
# 3  Pinot Grigio/Pinot Gris                         9.7
# 4                   Merlot                         6.4

# %%
# Set x- and y-axis and tick locations
x_axis = np.arange(0,len(variety_by_sales_data),1)
y_axis = variety_by_sales_data["Sales Percentage by Volume"]
tick_locations = [value for value in x_axis]

# Create a list indicating where to write x labels
plt.figure(figsize=(10,8))
ha = "right"
plt.bar(x_axis, y_axis, color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, variety_by_sales_data["Variety"], rotation=25, ha=ha)

# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(variety_by_sales_data["Sales Percentage by Volume"]) + 5)

# Set a title and labels
plt.title("Wine Variety vs. Sales Percentage by Volume (US)")
plt.xlabel("Wine Variety")
plt.ylabel("Sales Percentage by Volume (US)")

# Save our graph and show the graph
plt.tight_layout()
plt.savefig("out/Output1.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Question 2: Wine Variety vs. Mean Wine Score (US)

# %%
# Files to load
variety_by_sales_data_to_load = "csv/top_wine_variety_by_sales_volume.csv"
winemag_data_to_load = "csv/winemag_data_v2.csv"

# Read data
variety_by_sales_data = pd.read_csv(variety_by_sales_data_to_load)
winemag_data = pd.read_csv(winemag_data_to_load)

winemag_data_variety_score = winemag_data.drop(columns=["Unnamed: 0","description","region_2","taster_name",
                                                           "taster_twitter_handle","title"])

winemag_data_variety_score.head()
# Out:
#     country                         designation  points  price  \
# 0     Italy                        Vulkà Bianco      87    NaN
# 1  Portugal                            Avidagos      87   15.0
# 2        US                                 NaN      87   14.0
# 3        US                Reserve Late Harvest      87   13.0
# 4        US  Vintner's Reserve Wild Child Block      87   65.0
#
#             province             region_1         variety               winery
# 0  Sicily & Sardinia                 Etna     White Blend              Nicosia
# 1              Douro                  NaN  Portuguese Red  Quinta dos Avidagos
# 2             Oregon    Willamette Valley      Pinot Gris            Rainstorm
# 3           Michigan  Lake Michigan Shore        Riesling           St. Julian
# 4             Oregon    Willamette Valley      Pinot Noir         Sweet Cheeks

# %%
# Top 5 wine variety world mean wine scores (not used)

chardonnay = winemag_data_variety_score.loc[winemag_data_variety_score["variety"] == "Chardonnay"]
chardonnay_country = chardonnay.groupby("country")
chardonnay_country_average = chardonnay_country["points"].mean()

cabernet_sauvignon = winemag_data_variety_score.loc[winemag_data_variety_score["variety"] == "Cabernet Sauvignon"]
cabernet_sauvignon_country = cabernet_sauvignon.groupby("country")
cabernet_sauvignon_country_average = cabernet_sauvignon_country["points"].mean()

red_blend = winemag_data_variety_score.loc[winemag_data_variety_score["variety"] == "Red Blend"]
red_blend_country = red_blend.groupby("country")
red_blend_country_average = red_blend_country["points"].mean()

pinot_grigio = winemag_data_variety_score.loc[winemag_data_variety_score["variety"] == "Pinot Grigio"]
pinot_grigio_country = pinot_grigio.groupby("country")
pinot_grigio_country_average = pinot_grigio_country["points"].mean()

pinot_gris = winemag_data_variety_score.loc[winemag_data_variety_score["variety"] == "Pinot Gris"]
pinot_gris_country = pinot_gris.groupby("country")
pinot_gris_country_average = pinot_gris_country["points"].mean()

merlot = winemag_data_variety_score.loc[winemag_data_variety_score["variety"] == "Merlot"]
merlot_country = merlot.groupby("country")
merlot_country_average = merlot_country["points"].mean()

# summary dataframe
summary_table_2 = pd.DataFrame({"Chardonnay": chardonnay_country_average,
                                "Cabernet Sauvignon": cabernet_sauvignon_country_average,
                                "Red Blend": red_blend_country_average,
                                "Pinot Grigio": pinot_grigio_country_average,
                                "Pinot Gris": pinot_gris_country_average,
                                "Merlot": merlot_country_average})

summary_table_2.index.name = None
summary_table_2
# Out:
#                 Chardonnay  Cabernet Sauvignon  Red Blend  Pinot Grigio  \
# Argentina        84.945763           86.048148  88.397436     83.777778
# Australia        87.317500           89.251880  87.833333     86.000000
# Austria          90.301587           87.400000  89.913043           NaN
# Brazil           83.800000           83.000000  85.333333           NaN
# Bulgaria         88.500000           87.850000  89.181818     88.000000
# Canada           88.884615           90.000000  90.600000           NaN
# Chile            85.133721           86.688716  88.943765     83.000000
# Croatia                NaN                 NaN  87.666667           NaN
# Cyprus                 NaN                 NaN  87.000000           NaN
# Czech Republic         NaN                 NaN  89.000000           NaN
# England          92.388889                 NaN        NaN           NaN
# France           89.261040           85.438596  88.207237           NaN
# Georgia                NaN                 NaN  88.750000           NaN
# Germany          89.400000                 NaN  86.750000     88.000000
# Greece           87.533333           86.000000  87.058824           NaN
# Hungary          89.000000                 NaN  87.250000           NaN
# Israel           87.463415           88.828571  89.381579           NaN
# Italy            88.179641           89.137405  88.800221     86.560331
# Lebanon          88.000000                 NaN  87.937500           NaN
# Macedonia        87.000000                 NaN  86.000000           NaN
# Mexico           83.555556           84.250000  88.000000           NaN
# Moldova          86.500000           87.750000  87.818182     87.000000
# Morocco          88.333333                 NaN  89.625000           NaN
# New Zealand      88.752294           87.000000  89.000000     87.333333
# Peru             82.000000                 NaN  84.500000           NaN
# Portugal         87.647059           88.125000  88.571429           NaN
# Romania          86.333333           86.125000  87.600000     86.000000
# Serbia                 NaN                 NaN  89.000000           NaN
# Slovenia         88.750000           88.666667  88.500000     87.666667
# South Africa     88.380952           88.174242  88.827957           NaN
# Spain            84.837838           87.207547  88.154034           NaN
# Switzerland            NaN                 NaN        NaN           NaN
# Turkey           89.000000           89.000000  87.736842           NaN
# US               88.443611           89.025290  87.850942     85.891967
# Ukraine          85.000000           84.000000        NaN           NaN
# Uruguay          81.000000           87.000000  87.250000           NaN
#
#                 Pinot Gris     Merlot
# Argentina        84.888889  85.033898
# Australia        87.428571  85.736842
# Austria          90.066667  91.000000
# Brazil                 NaN  84.428571
# Bulgaria               NaN  87.692308
# Canada           90.250000  89.000000
# Chile                  NaN  85.244186
# Croatia          83.000000        NaN
# Cyprus                 NaN        NaN
# Czech Republic         NaN        NaN
# England                NaN        NaN
# France           89.633188  86.686957
# Georgia                NaN        NaN
# Germany          87.636364        NaN
# Greece                 NaN  88.166667
# Hungary          87.000000  89.000000
# Israel           90.000000  87.384615
# Italy                  NaN  89.480000
# Lebanon                NaN        NaN
# Macedonia              NaN        NaN
# Mexico                 NaN  82.000000
# Moldova          86.000000  86.500000
# Morocco                NaN        NaN
# New Zealand      87.677419  89.300000
# Peru                   NaN        NaN
# Portugal               NaN  88.142857
# Romania          86.666667  86.100000
# Serbia                 NaN        NaN
# Slovenia         88.666667  89.000000
# South Africa           NaN  86.529412
# Spain                  NaN  84.933333
# Switzerland            NaN  83.000000
# Turkey                 NaN  86.000000
# US               88.008065  87.386846
# Ukraine                NaN  84.000000
# Uruguay                NaN  84.000000

# %%
# Top 5 wine variety us mean wine scores

winemag_data_variety_score_us = winemag_data_variety_score.loc[winemag_data_variety_score["country"] == "US"]

chardonnay_us = winemag_data_variety_score_us.loc[winemag_data_variety_score_us["variety"] == "Chardonnay"]
chardonnay_us_average = chardonnay_us["points"].mean()

cabernet_sauvignon_us = winemag_data_variety_score_us.loc[winemag_data_variety_score_us["variety"] == "Cabernet Sauvignon"]
cabernet_sauvignon_us_average = cabernet_sauvignon_us["points"].mean()

red_blend_us = winemag_data_variety_score_us.loc[winemag_data_variety_score_us["variety"] == "Red Blend"]
red_blend_us_average = red_blend_us["points"].mean()

pinot_grigio_us = winemag_data_variety_score_us.loc[winemag_data_variety_score_us["variety"] == "Pinot Grigio"]
pinot_grigio_us_average = pinot_grigio_us["points"].mean()

pinot_gris_us = winemag_data_variety_score_us.loc[winemag_data_variety_score_us["variety"] == "Pinot Gris"]
pinot_gris_us_average = pinot_gris_us["points"].mean()

merlot_us = winemag_data_variety_score_us.loc[winemag_data_variety_score_us["variety"] == "Merlot"]
merlot_us_average = merlot_us["points"].mean()

# summary dataframe
summary_table_2_us = pd.DataFrame({
    "Wine Variety": ["Chardonnay", "Cabernet Sauvignon", "Red Blend", "Pinot Grigio/Pinot Gris", "Merlot"],
    "Mean Wine Score": [chardonnay_us_average, cabernet_sauvignon_us_average, red_blend_us_average, 
                        (pinot_grigio_us_average + pinot_gris_us_average)/2, merlot_us_average]
})

summary_table_2_us.index.name = None
summary_table_2_us
# Out:
#               Wine Variety  Mean Wine Score
# 0               Chardonnay        88.443611
# 1       Cabernet Sauvignon        89.025290
# 2                Red Blend        87.850942
# 3  Pinot Grigio/Pinot Gris        86.950016
# 4                   Merlot        87.386846

# %%
# Set x- and y-axis and tick locations
x_axis = np.arange(0,len(summary_table_2_us),1)
y_axis = summary_table_2_us["Mean Wine Score"]
tick_locations = [value for value in x_axis]

# Create a list indicating where to write x labels
ha = "right"
plt.bar(x_axis, y_axis, color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, summary_table_2_us["Wine Variety"], rotation=25, ha=ha)

# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(80, 100)

# Set a title and labels
plt.title("Wine Variety vs. Mean Wine Score (US)")
plt.xlabel("Wine Variety")
plt.ylabel("Mean Wine Score (US)")

# Save our graph and show the graph
plt.tight_layout()
plt.savefig("out/Output2.png")
plt.show()

# %% [markdown]
# Question 3: California Region vs. Mean Wine Score (US-CA)

# %%
# Files to load
variety_by_sales_data_to_load = "csv/top_wine_variety_by_sales_volume.csv"
winemag_data_to_load = "csv/winemag_data_v2.csv"

# Read data
variety_by_sales_data = pd.read_csv(variety_by_sales_data_to_load)
winemag_data = pd.read_csv(winemag_data_to_load)

winemag_data_variety_score = winemag_data.drop(columns=["Unnamed: 0","description","region_2","taster_name",
                                                           "taster_twitter_handle","title"])

winemag_data_variety_score.head()
# Out:
#     country                         designation  points  price  \
# 0     Italy                        Vulkà Bianco      87    NaN
# 1  Portugal                            Avidagos      87   15.0
# 2        US                                 NaN      87   14.0
# 3        US                Reserve Late Harvest      87   13.0
# 4        US  Vintner's Reserve Wild Child Block      87   65.0
#
#             province             region_1         variety               winery
# 0  Sicily & Sardinia                 Etna     White Blend              Nicosia
# 1              Douro                  NaN  Portuguese Red  Quinta dos Avidagos
# 2             Oregon    Willamette Valley      Pinot Gris            Rainstorm
# 3           Michigan  Lake Michigan Shore        Riesling           St. Julian
# 4             Oregon    Willamette Valley      Pinot Noir         Sweet Cheeks

# %%
# California region mean wine scores
winemag_data_variety_score_ca = winemag_data_variety_score.loc[winemag_data_variety_score["province"] == "California"]
winemag_data_variety_score_ca_region = winemag_data_variety_score_ca.groupby("region_1")
winemag_data_variety_score_ca_region_average = winemag_data_variety_score_ca_region["points"].mean()

# summary dataframe
summary_table_3 = pd.DataFrame({"Mean Wine Score": winemag_data_variety_score_ca_region_average})
summary_table_3 = summary_table_3.sort_values("Mean Wine Score",ascending=False)

summary_table_3.index.name = None
summary_table_3_top5 = summary_table_3.head()
summary_table_3_top5
# Out:
#                          Mean Wine Score
# Napa-Monterey-Mendocino        96.000000
# McDowell Valley                94.000000
# Fort Ross-Seaview              92.546875
# Monterey-Santa Cruz            92.000000
# Ballard Canyon                 91.746835

# %%
# Set x- and y-axis and tick locations
x_axis = np.arange(0,len(summary_table_3_top5),1)
y_axis = summary_table_3_top5["Mean Wine Score"]
tick_locations = [value for value in x_axis]

# Create a list indicating where to write x labels
ha = "right"
plt.bar(x_axis, y_axis, color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, summary_table_3.index, rotation=25, ha=ha)

# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(80, 100)

# Set a title and labels
plt.title("California Region vs. Mean Wine Score (US-CA)")
plt.xlabel("California Region")
plt.ylabel("Mean Wine Score (US-CA)")

# Save our graph and show the graph
plt.tight_layout()
plt.savefig("out/Output3.png")
plt.show()

# %% [markdown]
# #Regina's Question1 - Wine Producers by State

# %%
q2_csv = "./csv/q2-bonded-wine-producers-by-state-1999-june-2019.csv"
q2_csv_df = pd.read_csv(q2_csv, encoding="latin")
q2_csv_df.fillna("",inplace=True)
#q2_csv_df.tail()

# %%
producers_2018 = q2_csv_df['2018']
#producers_2018.head()

# %%
prod_states = q2_csv_df['State']
#prod_states.head()

# %%
producers_2018_df=pd.concat([prod_states, producers_2018], axis=1)
#producers_2018_df.head()

# %%
x_axis = np.arange(0,len(q2_csv_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)


plt.title("Wine Producers by State - U.S.")  
plt.ylabel("Number of Producers")


plt.figure(figsize=(20,3))
plt.bar(x_axis,producers_2018_df['2018'], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, producers_2018_df['State'], rotation='vertical')
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x246dbd8ea20>,
#   <matplotlib.axis.XTick at 0x246dbd8e390>,
#   <matplotlib.axis.XTick at 0x246dbd8e240>,
#   <matplotlib.axis.XTick at 0x246dadad1d0>,
#   <matplotlib.axis.XTick at 0x246dadad668>,
#   <matplotlib.axis.XTick at 0x246dadadb38>,
#   <matplotlib.axis.XTick at 0x246dadadd68>,
#   <matplotlib.axis.XTick at 0x246dad83278>,
#   <matplotlib.axis.XTick at 0x246dad83748>,
#   <matplotlib.axis.XTick at 0x246dad83c18>,
#   <matplotlib.axis.XTick at 0x246dad84160>,
#   <matplotlib.axis.XTick at 0x246dad845f8>,
#   <matplotlib.axis.XTick at 0x246dad84ac8>,
#   <matplotlib.axis.XTick at 0x246dad84e80>,
#   <matplotlib.axis.XTick at 0x246dad84940>,
#   <matplotlib.axis.XTick at 0x246dad83be0>,
#   <matplotlib.axis.XTick at 0x246dad9d400>,
#   <matplotlib.axis.XTick at 0x246dad9d978>,
#   <matplotlib.axis.XTick at 0x246dad9de80>,
#   <matplotlib.axis.XTick at 0x246dad7d3c8>,
#   <matplotlib.axis.XTick at 0x246dad7d8d0>,
#   <matplotlib.axis.XTick at 0x246dad7ddd8>,
#   <matplotlib.axis.XTick at 0x246defdc320>,
#   <matplotlib.axis.XTick at 0x246defdc828>,
#   <matplotlib.axis.XTick at 0x246dad7d9b0>,
#   <matplotlib.axis.XTick at 0x246dadadc50>,
#   <matplotlib.axis.XTick at 0x246defdc128>,
#   <matplotlib.axis.XTick at 0x246defd2128>,
#   <matplotlib.axis.XTick at 0x246defd25c0>,
#   <matplotlib.axis.XTick at 0x246defd2ac8>,
#   <matplotlib.axis.XTick at 0x246defd2c88>,
#   <matplotlib.axis.XTick at 0x246defc1518>,
#   <matplotlib.axis.XTick at 0x246defc1a20>,
#   <matplotlib.axis.XTick at 0x246defc1f28>,
#   <matplotlib.axis.XTick at 0x246defd2b70>,
#   <matplotlib.axis.XTick at 0x246defdc2e8>,
#   <matplotlib.axis.XTick at 0x246defc8320>,
#   <matplotlib.axis.XTick at 0x246defc8828>,
#   <matplotlib.axis.XTick at 0x246defc8d30>,
#   <matplotlib.axis.XTick at 0x246defba208>,
#   <matplotlib.axis.XTick at 0x246defba748>,
#   <matplotlib.axis.XTick at 0x246defbac50>,
#   <matplotlib.axis.XTick at 0x246defa7198>,
#   <matplotlib.axis.XTick at 0x246defbaac8>,
#   <matplotlib.axis.XTick at 0x246defc88d0>,
#   <matplotlib.axis.XTick at 0x246defc1ef0>,
#   <matplotlib.axis.XTick at 0x246defa7588>,
#   <matplotlib.axis.XTick at 0x246defa7a90>,
#   <matplotlib.axis.XTick at 0x246defa7e80>,
#   <matplotlib.axis.XTick at 0x246def8b4e0>,
#   <matplotlib.axis.XTick at 0x246def8b9e8>],
#  <a list of 51 Text xticklabel objects>)

# %%
plt.show()
plt.savefig('wineproducers_state_bar.png')

# %% [markdown]
# #Regina's Question2 - Wine Sales by State

# %%
data = "./csv/wine_sales_2018.csv"
wine_sales = pd.read_csv(data)
#wine_sales.head()

# %%
df=pd.DataFrame(wine_sales)
df=df.set_index('Year')
#df.head()

# %%
#print(df.iloc[0],[6])

# %%
labels = ["Table Wine", "Dessert Wine", "Sparkling Wine/Champagne"]
value =[338.7,40.4,27.4]
total = [406.5]
explode = (0.1, 0,0)
colors = ["maroon", "yellow", "lightcoral", "orange" ]
plt.title("2018 U.S. Wine Sales" )
plt.pie(value, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x246deccdb38>,
#   <matplotlib.patches.Wedge at 0x246def5c4a8>,
#   <matplotlib.patches.Wedge at 0x246def35fd0>],
#  [Text(0.4099884625620273, -1.127789634890313, 'Table Wine'),
#   Text(-0.15014351906712523, 1.0897049709357758, 'Dessert Wine'),
#   Text(-0.6752162112804365, 0.8683795644901445, 'Sparkling Wine/Champagne')],
#  [Text(0.2391599364945159, -0.6578772870193492, '83.3%'),
#   Text(-0.08189646494570467, 0.5943845296013323, '9.9%'),
#   Text(-0.36829975160751083, 0.47366158063098784, '6.7%')])

# %%
plt.savefig('wine_sales_pie2018.png')

# %% [markdown]
# Regina's Question3 - Wine Sales by Top Variety

# %%
plt.rcdefaults()
top_wine_types_csv = "./csv/top_wine_Variety_sales_vol.csv"
top_wine_types = pd.read_csv(top_wine_types_csv, encoding="latin")
#top_wine_types.head()

# %%
df=pd.DataFrame(top_wine_types)
df=df.set_index('Rank')
#df

# %%
x_axis = np.arange(0,len(df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

#plt.xlim(-0.75, len(q2_csv_df)-0.25)
#plt.ylim(ymax=20, ymin=1)

plt.figure(figsize=(20,20))
plt.bar(x_axis,df['Sales Percentage by Volume'], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, df['Variety'], rotation='vertical')

plt.title("Top Wine Varieties by Volume Sales Percentage - U.S.")  
plt.xlabel("Wine Varities")
plt.ylabel("Percentage of 2018 Sales")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# Text(0, 0.5, 'Percentage of 2018 Sales')

# %%
plt.show()
plt.savefig('tops_chart1_bar.png')

# %% [markdown]
# Adam Durar
#
# Question 1 - Of the top 5 highest possible wine scores (96-100) from WineEnthusiast, what are the top 10 overall wines that offer the best "bang for your buck" based on rating vs. price?

# %%
wine_data = "csv/winemag_data_v2.csv"

# %%
wine_data = pd.read_csv(wine_data)
wine_data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_data_update = wine_data.drop(columns=["Unnamed: 0","description","region_1","region_2","taster_name","taster_twitter_handle"])

# %%
wine_data_update_even = wine_data_update.dropna(subset=['price'])

# %%
wine_data_update_even = wine_data_update_even.sort_values(by = 'points', ascending=False)

# %%
wine_data_update_even=wine_data_update_even.reset_index(drop=True)

# %%
wine_data_new_even_96above = wine_data_update_even[wine_data_update_even['points']>=96]

# %%
new_price=wine_data_new_even_96above['price'].astype(str).replace('\.0', '', regex=True)

# %%
winefinal_df = pd.DataFrame(wine_data_new_even_96above) 

winefinal_df['Price'] = new_price

winefinal_df['Price'] = winefinal_df['Price'].astype(int)

winefinal_df = winefinal_df.drop(columns=['price'])

winefinal_df = winefinal_df.rename(columns={"country": "Country", "designation": "Designation", "points": "Points", 
                                            "province": "Province", "title": "Title", "variety": "Variety", "winery": "Winery"})
winefinal_df = winefinal_df[['Country','Designation','Province', 'Title', 'Variety', 'Winery', 'Points', 'Price']]
winefinal_df.head()
# Out:
#   Country                     Designation   Province  \
# 0  France                             NaN   Bordeaux
# 1  France            Cristal Vintage Brut  Champagne
# 2  France  Le Mesnil Blanc de Blancs Brut  Champagne
# 3  France                             NaN   Bordeaux
# 4  France                             NaN   Bordeaux
#
#                                                Title  \
# 0            Château Haut-Brion 2014  Pessac-Léognan
# 1  Louis Roederer 2008 Cristal Vintage Brut  (Cha...
# 2  Salon 2006 Le Mesnil Blanc de Blancs Brut Char...
# 3         Château Léoville Barton 2010  Saint-Julien
# 4      Château Léoville Las Cases 2010  Saint-Julien
#
#                       Variety                      Winery  Points  Price
# 0  Bordeaux-style White Blend          Château Haut-Brion     100    848
# 1             Champagne Blend              Louis Roederer     100    250
# 2                  Chardonnay                       Salon     100    617
# 3    Bordeaux-style Red Blend     Château Léoville Barton     100    150
# 4    Bordeaux-style Red Blend  Château Léoville Las Cases     100    359

# %%
points=winefinal_df['Points']

price=winefinal_df['Price']

value_score=(points-price)

# %%
winefinal_df['Bang For Buck Score'] = value_score

# %%
winefinal_df = winefinal_df.sort_values(by = 'Bang For Buck Score', ascending=False)
winefinal_df=winefinal_df.reset_index(drop=True)

# %%
winefinal_df_topten_new = winefinal_df[winefinal_df['Bang For Buck Score']>=65]

# %%
rank = ["1", "2(tie)", "2(tie)", "2(tie)", "5(tie)", "5(tie)", "7", "8(tie)", "8(tie)", "8(tie)"]

# %%
winefinal_df_topten_new['Rank'] = rank
# Out:
# C:\Users\adamd\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
winefinal_df_topten_final = winefinal_df_topten_new[['Rank','Bang For Buck Score','Points', 'Price', 'Title', 'Winery', 'Variety', 'Country', 'Province', 'Designation']]

winefinal_df_topten_final = winefinal_df_topten_final.set_index('Rank')

# %%
winefinal_df_topten_final
# Out:
#         Bang For Buck Score  Points  Price  \
# Rank
# 1                        76      96     20
# 2(tie)                   69      96     27
# 2(tie)                   69      96     27
# 2(tie)                   69      96     27
# 5(tie)                   68      96     28
# 5(tie)                   68      96     28
# 7                        67      96     29
# 8(tie)                   66      96     30
# 8(tie)                   66      96     30
# 8(tie)                   66      96     30
#
#                                                     Title  \
# Rank
# 1                  Rulo 2007 Syrah (Columbia Valley (WA))
# 2(tie)  The Eyrie Vineyards 2014 Estate Chardonnay (Du...
# 2(tie)               Isole e Olena 2010  Chianti Classico
# 2(tie)  Donkey & Goat 2012 Grenache Noir Grenache (El ...
# 5(tie)  Eichinger 2014 Gaisberg Reserve Riesling (Kamp...
# 5(tie)                     Château Filhot 2014  Sauternes
# 7       Domaines Schlumberger 2014 Saering Grand Cru R...
# 8(tie)    Sineann 2015 TFL Pinot Noir (Willamette Valley)
# 8(tie)  Alvear NV Solera 1927 Pedro Ximénez (Montilla-...
# 8(tie)  Efeste 2009 Lola Chardonnay (Columbia Valley (...
#
#                        Winery                     Variety  Country  \
# Rank
# 1                        Rulo                       Syrah       US
# 2(tie)    The Eyrie Vineyards                  Chardonnay       US
# 2(tie)          Isole e Olena                   Red Blend    Italy
# 2(tie)          Donkey & Goat                    Grenache       US
# 5(tie)              Eichinger                    Riesling  Austria
# 5(tie)         Château Filhot  Bordeaux-style White Blend   France
# 7       Domaines Schlumberger                    Riesling   France
# 8(tie)                Sineann                  Pinot Noir       US
# 8(tie)                 Alvear               Pedro Ximénez    Spain
# 8(tie)                 Efeste                  Chardonnay       US
#
#           Province        Designation
# Rank
# 1       Washington                NaN
# 2(tie)      Oregon             Estate
# 2(tie)     Tuscany                NaN
# 2(tie)  California      Grenache Noir
# 5(tie)     Kamptal   Gaisberg Reserve
# 5(tie)    Bordeaux                NaN
# 7           Alsace  Saering Grand Cru
# 8(tie)      Oregon                TFL
# 8(tie)   Andalucia        Solera 1927
# 8(tie)  Washington               Lola

# %%
winefinal_df_topten_final.to_csv("csv/BangForBuckTop10.csv")

# %%
x_limit = 100
x_axis = np.arange(0, x_limit, 10)


y_limit = 101
y_axis = np.arange(95, y_limit, 1)

plt.figure(figsize=(20,10))
plt.scatter(price, points, marker="o", facecolors="red", edgecolors="black", alpha=1)

plt.title("WineEnthusiast 2017 Wine Ratings - 96 Rating & Above", fontsize=30)
plt.xlabel("Price (USD)", fontsize=15)
plt.ylabel("Points Score (Rating)", fontsize=15)

plt.xlim(0, x_limit)
plt.ylim(95, y_limit)

plt.grid()

plt.savefig("out/wine_BangForBuck_scatter_plot.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
topten = winefinal_df_topten_final["Bang For Buck Score"]

winetext = winefinal_df_topten_final["Title"]

x = np.arange(len(topten))  # the label locations
width = 0.5

fig, ax = plt.subplots(figsize=(20,20))
rects1 = ax.bar(x - width/2, topten, width, color='r', alpha=1.0, align="center")

ax.set_xlabel("Wine", fontsize=20)
ax.set_ylabel("Bang For Buck Score (Points Score - Price)", fontsize=20)
ax.set_title("Top 10 Wines - Best Bang For Your Buck", fontsize=35)
ax.set_xticks(x - width / 2)
ax.set_xticklabels(winetext, rotation=25, fontsize=15, ha="right")

def autolabel(rects):
    
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=15)

autolabel(rects1)


plt.xlim(-0.75, len(x_axis)-0.25)

plt.ylim(0, 85)
plt.tight_layout()
plt.savefig("out/top10_barchart.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %% [markdown]
# Adam Durar
#
# Question 1(b) - What are the top "Bang for Buck" (rating - price) wines from WineEnthusiast that scored ratings between 97-100?

# %%
wine_data_new_even_97above = wine_data_update_even[wine_data_update_even['points']>=97]

# %%
new_price_97=wine_data_new_even_97above['price'].astype(str).replace('\.0', '', regex=True)

# %%
winefinal_df_97above = pd.DataFrame(wine_data_new_even_97above) 

winefinal_df_97above['Price'] = new_price_97

winefinal_df_97above['Price'] = winefinal_df_97above['Price'].astype(int)

winefinal_df_97above = winefinal_df_97above.drop(columns=['price'])

winefinal_df_97above = winefinal_df_97above.rename(columns={"country": "Country", "designation": "Designation", "points": "Points", 
                                            "province": "Province", "title": "Title", "variety": "Variety", "winery": "Winery"})


winefinal_df_97above = winefinal_df_97above[['Country','Designation','Province', 'Title', 'Variety', 'Winery', 'Points', 'Price']]

# %%
points_97=winefinal_df_97above['Points']


price_97=winefinal_df_97above['Price']


value_score_97=(points_97-price_97)

# %%
winefinal_df_97above['Bang For Buck Score'] = value_score_97

# %%
winefinal_df_97above = winefinal_df_97above.sort_values(by = 'Bang For Buck Score', ascending=False)
winefinal_df_97above=winefinal_df_97above.reset_index(drop=True)

# %%
winefinal_df_97above.head(70)
# Out:
#      Country                             Designation           Province  \
# 0         US                      Fenaughty Vineyard         California
# 1   Portugal                         325 Anniversary               Port
# 2         US                         Estate Vineyard         California
# 3     France                                     NaN           Bordeaux
# 4         US                                Red Wine         Washington
# 5         US                             Rocky Knoll         California
# 6         US                          Allen Vineyard         California
# 7     France  Clos Saint Landelin Vorbourg Grand Cru             Alsace
# 8         US              Dutton Ranch Rued Vineyard         California
# 9         US                                  Estate         California
# 10        US                 Trenton Estate Vineyard         California
# 11        US                     Ferrington Vineyard         California
# 12        US                         Meredith Estate         California
# 13        US                               Lagniappe         Washington
# 14    France                                     NaN           Bordeaux
# 15        US                         Père de Famille         Washington
# 16     Italy                                  Bussia           Piedmont
# 17     Italy                          Rabajà Riserva           Piedmont
# 18        US                         Garys' Vineyard         California
# 19        US                         Bucher Vineyard         California
# 20        US                                     NaN         California
# 21     Italy                                 Cannubi           Piedmont
# 22        US                    South River Vineyard         California
# 23        US               Occidental Ridge Vineyard         California
# 24     Italy                              Contrada R  Sicily & Sardinia
# 25        US                        Ritchie Vineyard         California
# 26        US                                     NaN         California
# 27        US                   Abbott Claim Vineyard             Oregon
# 28    France                    Muenchberg Grand Cru             Alsace
# 29        US                 Westside Road Neighbors         California
# ..       ...                                     ...                ...
# 40     Italy                                     NaN            Tuscany
# 41        US                       Cailloux Vineyard         Washington
# 42        US                              The Hidden         Washington
# 43        US                         Hirsch Vineyard         California
# 44        US                             Moon Select         California
# 45        US                     Rosemary's Vineyard         California
# 46        US                      Hawk Hill Vineyard         California
# 47        US                  En Chamberlin Vineyard             Oregon
# 48        US                         Hirsch Vineyard         California
# 49        US                  En Chamberlin Vineyard             Oregon
# 50        US                      En Cerise Vineyard             Oregon
# 51        US                     Coastlands Vineyard         California
# 52        US                     Coastlands Vineyard         California
# 53        US                                     NaN         California
# 54  Portugal                                     NaN           Alentejo
# 55     Italy                                Badarina           Piedmont
# 56        US                     Confluence Vineyard         California
# 57        US                      Black Cougar Ridge         California
# 58        US                        Six White Horses         California
# 59     Italy                                   Prapò           Piedmont
# 60        US                              Royal City         Washington
# 61        US                             Bionic Frog         Washington
# 62        US                          Allen Vineyard         California
# 63        US            Rochioli Riverblock Vineyard         California
# 64        US                       Wayfarer Vineyard         California
# 65   Hungary             6 Puttonyos Aszú Gold Label             Tokaji
# 66     Italy                            Tenuta Nuova            Tuscany
# 67        US                          The Widowmaker             Oregon
# 68     Italy                            Bussia 90 Dì           Piedmont
# 69     Italy                                Excelsus            Tuscany
#
#                                                 Title  \
# 0   Donkey & Goat 2010 Fenaughty Vineyard Syrah (E...
# 1          Taylor Fladgate NV 325 Anniversary  (Port)
# 2   Failla 2010 Estate Vineyard Chardonnay (Sonoma...
# 3                         Château Coutet 2014  Barsac
# 4   Pirouette 2008 Red Wine Red (Columbia Valley (...
# 5   Limerick Lane 2013 Rocky Knoll Zinfandel (Russ...
# 6   Williams Selyem 2010 Allen Vineyard Chardonnay...
# 7   René Muré 2015 Clos Saint Landelin Vorbourg Gr...
# 8   Dutton-Goldfield 2010 Dutton Ranch Rued Vineya...
# 9   Trefethen 2005 Estate Cabernet Sauvignon (Oak ...
# 10  Joseph Swan Vineyards 2007 Trenton Estate Vine...
# 11  Arista 2005 Ferrington Vineyard Pinot Noir (An...
# 12  Merry Edwards 2007 Meredith Estate Pinot Noir ...
# 13  Gramercy 2010 Lagniappe Syrah (Columbia Valley...
# 14                Clos Haut-Peyraguey 2014  Sauternes
# 15  Betz Family 2005 Père de Famille Cabernet Sauv...
# 16            Giacomo Fenocchio 2013 Bussia  (Barolo)
# 17  Produttori del Barbaresco 2011 Rabajà Riserva ...
# 18  Roar 2014 Garys' Vineyard Pinot Noir (Santa Lu...
# 19  Williams Selyem 2012 Bucher Vineyard Pinot Noi...
# 20               Mt. Brave 2008 Merlot (Mount Veeder)
# 21                      Brezza 2013 Cannubi  (Barolo)
# 22  Rochioli 2010 South River Vineyard Chardonnay ...
# 23  Failla 2010 Occidental Ridge Vineyard Pinot No...
# 24  Passopisciaro 2013 Contrada R Nerello Mascales...
# 25  Ramey 2012 Ritchie Vineyard Chardonnay (Russia...
# 26        Redmon 2006 Cabernet Sauvignon (St. Helena)
# 27   Ken Wright 2012 Abbott Claim Vineyard Pinot Noir
# 28  Domaine Ostertag 2015 Muenchberg Grand Cru Rie...
# 29  Williams Selyem 2013 Westside Road Neighbors P...
# ..                                                ...
# 40          Le Potazzine 2011  Brunello di Montalcino
# 41  Cayuse 2008 Cailloux Vineyard Syrah (Walla Wal...
# 42   K Vintners 2009 The Hidden Syrah (Wahluke Slope)
# 43  Failla 2010 Hirsch Vineyard Pinot Noir (Sonoma...
# 44  Flowers 2011 Moon Select Chardonnay (Sonoma Co...
# 45  Talley 2005 Rosemary's Vineyard Pinot Noir (Ar...
# 46  Lynmar 2007 Hawk Hill Vineyard Pinot Noir (Rus...
# 47  Cayuse 2009 En Chamberlin Vineyard Syrah (Wall...
# 48  Williams Selyem 2010 Hirsch Vineyard Pinot Noi...
# 49  Cayuse 2011 En Chamberlin Vineyard Syrah (Wall...
# 50  Cayuse 2011 En Cerise Vineyard Syrah (Walla Wa...
# 51  Williams Selyem 2013 Coastlands Vineyard Pinot...
# 52  Williams Selyem 2014 Coastlands Vineyard Pinot...
# 53      Vine Cliff 2007 Cabernet Sauvignon (Oakville)
# 54                        Mouchão 2012 Red (Alentejo)
# 55             Grimaldi Bruna 2013 Badarina  (Barolo)
# 56  Goldeneye 2007 Confluence Vineyard Pinot Noir ...
# 57  Stonestreet 2007 Black Cougar Ridge Cabernet S...
# 58   Sanguis 2009 Six White Horses Syrah (California)
# 59                Germano Ettore 2013 Prapò  (Barolo)
# 60  Charles Smith 2006 Royal City Syrah (Columbia ...
# 61  Cayuse 2008 Bionic Frog Syrah (Walla Walla Val...
# 62  Williams Selyem 2007 Allen Vineyard Pinot Noir...
# 63  Williams Selyem 2013 Rochioli Riverblock Viney...
# 64  Wayfarer 2014 Wayfarer Vineyard Chardonnay (Fo...
# 65  Royal Tokaji 2013 6 Puttonyos Aszú Gold Label ...
# 66  Casanova di Neri 2006 Tenuta Nuova  (Brunello ...
# 67  Cayuse 2009 The Widowmaker Cabernet Sauvignon ...
# 68      Giacomo Fenocchio 2008 Bussia 90 Dì  (Barolo)
# 69         Castello Banfi 2007 Excelsus Red (Toscana)
#
#                        Variety                     Winery  Points  Price  \
# 0                        Syrah              Donkey & Goat      97     35
# 1                         Port            Taylor Fladgate      97     40
# 2                   Chardonnay                     Failla      99     44
# 3   Bordeaux-style White Blend             Château Coutet      97     45
# 4     Bordeaux-style Red Blend                  Pirouette      98     50
# 5                    Zinfandel              Limerick Lane      97     50
# 6                   Chardonnay            Williams Selyem      97     50
# 7                     Riesling                  René Muré      97     50
# 8                   Chardonnay           Dutton-Goldfield      97     50
# 9           Cabernet Sauvignon                  Trefethen      97     50
# 10                  Pinot Noir      Joseph Swan Vineyards      97     52
# 11                  Pinot Noir                     Arista      97     54
# 12                  Pinot Noir              Merry Edwards      97     54
# 13                       Syrah                   Gramercy      98     55
# 14  Bordeaux-style White Blend        Clos Haut-Peyraguey      97     55
# 15          Cabernet Sauvignon                Betz Family      97     55
# 16                    Nebbiolo          Giacomo Fenocchio      97     55
# 17                    Nebbiolo  Produttori del Barbaresco      97     58
# 18                  Pinot Noir                       Roar      97     58
# 19                  Pinot Noir            Williams Selyem      97     59
# 20                      Merlot                  Mt. Brave      98     60
# 21                    Nebbiolo                     Brezza      98     60
# 22                  Chardonnay                   Rochioli      97     60
# 23                  Pinot Noir                     Failla      97     60
# 24           Nerello Mascalese              Passopisciaro      97     60
# 25                  Chardonnay                      Ramey      97     65
# 26          Cabernet Sauvignon                     Redmon      97     65
# 27                  Pinot Noir                 Ken Wright      97     65
# 28                    Riesling           Domaine Ostertag      97     66
# 29                  Pinot Noir            Williams Selyem      98     69
# ..                         ...                        ...     ...    ...
# 40                  Sangiovese               Le Potazzine      97     70
# 41                       Syrah                     Cayuse      97     70
# 42                       Syrah                 K Vintners      97     70
# 43                  Pinot Noir                     Failla      97     70
# 44                  Chardonnay                    Flowers      97     70
# 45                  Pinot Noir                     Talley      97     70
# 46                  Pinot Noir                     Lynmar      97     70
# 47                       Syrah                     Cayuse      99     75
# 48                  Pinot Noir            Williams Selyem      99     75
# 49                       Syrah                     Cayuse      99     75
# 50                       Syrah                     Cayuse      98     75
# 51                  Pinot Noir            Williams Selyem      98     75
# 52                  Pinot Noir            Williams Selyem      98     75
# 53          Cabernet Sauvignon                 Vine Cliff      98     75
# 54              Portuguese Red                    Mouchão      97     75
# 55                    Nebbiolo             Grimaldi Bruna      97     75
# 56                  Pinot Noir                  Goldeneye      97     75
# 57          Cabernet Sauvignon                Stonestreet      97     75
# 58                       Syrah                    Sanguis      97     75
# 59                    Nebbiolo             Germano Ettore      97     75
# 60                       Syrah              Charles Smith     100     80
# 61                       Syrah                     Cayuse     100     80
# 62                  Pinot Noir            Williams Selyem      97     78
# 63                  Pinot Noir            Williams Selyem      97     79
# 64                  Chardonnay                   Wayfarer      98     80
# 65                 White Blend               Royal Tokaji      97     80
# 66           Sangiovese Grosso           Casanova di Neri      97     80
# 67          Cabernet Sauvignon                     Cayuse      97     80
# 68                    Nebbiolo          Giacomo Fenocchio      97     80
# 69                   Red Blend             Castello Banfi      97     81
#
#     Bang For Buck Score
# 0                    62
# 1                    57
# 2                    55
# 3                    52
# 4                    48
# 5                    47
# 6                    47
# 7                    47
# 8                    47
# 9                    47
# 10                   45
# 11                   43
# 12                   43
# 13                   43
# 14                   42
# 15                   42
# 16                   42
# 17                   39
# 18                   39
# 19                   38
# 20                   38
# 21                   38
# 22                   37
# 23                   37
# 24                   37
# 25                   32
# 26                   32
# 27                   32
# 28                   31
# 29                   29
# ..                  ...
# 40                   27
# 41                   27
# 42                   27
# 43                   27
# 44                   27
# 45                   27
# 46                   27
# 47                   24
# 48                   24
# 49                   24
# 50                   23
# 51                   23
# 52                   23
# 53                   23
# 54                   22
# 55                   22
# 56                   22
# 57                   22
# 58                   22
# 59                   22
# 60                   20
# 61                   20
# 62                   19
# 63                   18
# 64                   18
# 65                   17
# 66                   17
# 67                   17
# 68                   17
# 69                   16
#
# [70 rows x 9 columns]
