# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json

# %%
q2_csv = "q2-bonded-wine-producers-by-state-1999-june-2019.csv"
q2_csv_df = pd.read_csv(q2_csv, encoding="latin")
q2_csv_df.head()
# Out:
#      Unnamed: 0   1999   2000   2001   2002   2003   2004   2005   2006  \
# 0  St abbr Addr  COUNT  COUNT  COUNT  COUNT  COUNT  COUNT  COUNT  COUNT
# 1            AK      4      4      4      4      4      6      6      9
# 2            AL      4      5      6      5      5      5      8      8
# 3            AR     11     11     10     10     10      8      8     11
# 4            AZ     12     10     11     13     13     19     21     27
#
#     2007  ...   2011   2012   2013   2014   2015   2016   2017   2018  \
# 0  COUNT  ...  COUNT  COUNT  COUNT  COUNT  COUNT  COUNT  COUNT  COUNT
# 1      9  ...      8      8     10      9      6      7      7     10
# 2      9  ...     16     18     21     25     29     33     37     42
# 3     13  ...     17     20     25     29     30     30     34     36
# 4     33  ...     52     58     66     71     75     87     94    111
#
#   Through 3/31/2019 Through 6/30/2019
# 0             COUNT             COUNT
# 1                10                11
# 2                42                47
# 3                36                35
# 4               118               122
#
# [5 rows x 23 columns]

# %%
x_axis = np.arange(len(q2_csv_df))
tick_locations = [value for value in x_axis]


plt.bar(x_axis, users, color='r', alpha=0.5, align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations,["1999", "2000", "2001", "2003", "2004", "2005",
                           "2006", "2007", "2008", "2009", "2010", "2011",
                           "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"])
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-823d7b3a31b4> in <module>
# ----> 1 plt.bar(x_axis, users, color='r', alpha=0.5, align="center")
#       2 tick_locations = [value for value in x_axis]
#       3 plt.xticks(tick_locations,["1999", "2000", "2001", "2003", "2004", "2005",
#       4                            "2006", "2007", "2008", "2009", "2010", "2011",
#       5                            "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"])
#
# NameError: name 'x_axis' is not defined
