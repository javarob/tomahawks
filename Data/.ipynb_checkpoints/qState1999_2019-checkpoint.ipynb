# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
plt.rcdefaults()

# %%
q2_csv = "q2-bonded-wine-producers-by-state-1999-june-2019.csv"
q2_csv_df = pd.read_csv(q2_csv, encoding="latin")
q2_csv_df.fillna("",inplace=True)
q2_csv_df.tail()
# Out:
#    State 1999 2000 2001 2002 2003 2004 2005 2006 2007  ... 2011 2012 2013  \
# 46    VT   10   10    8    8    8   10   10   15   17  ...   35   37   42
# 47    WA  163  182  231  268  325  376  454  527  578  ...  804  849  915
# 48    WI   20   24   26   27   29   35   40   41   48  ...   88  103  113
# 49    WV   13   15   16   16   16   17   18   19   19  ...   24   26   29
# 50    WY                                               ...    *    5    6
#
#    2014 2015  2016  2017  2018 Through 3/31/2019  Through 6/30/2019
# 46   43   47    51    68    71                76                 79
# 47  989  985  1019  1091  1171              1202               1218
# 48  131  138   139   149   168               182                186
# 49   30   30    32    37    37                39                 39
# 50    7    8     8     8     9                10                 10
#
# [5 rows x 23 columns]

# %%
producers_2018 = q2_csv_df['2018']
producers_2018.head()
# Out:
# 0      10
# 1      42
# 2      36
# 3     111
# 4    5217
# Name: 2018, dtype: int64

# %%
prod_states = q2_csv_df['State']
prod_states.head()
# Out:
# 0    AK
# 1    AL
# 2    AR
# 3    AZ
# 4    CA
# Name: State, dtype: object

# %%
#years = q2_csv_df.keys()
#columns =pd.DataFrame(years)
#columns.head()

# %%
producers_2018_df=pd.concat([prod_states, producers_2018], axis=1)
producers_2018_df.head()
#wine2018_df = producers_2018_df.astype({'States':'float64', '2018':'float64'})
#wine2018_df.head()
# Out:
#   State  2018
# 0    AK    10
# 1    AL    42
# 2    AR    36
# 3    AZ   111
# 4    CA  5217

# %%
lgprodstate = producers_2018_df.iloc(max[State].value)

# %%
#state_and_2018 = q2_csv_df[['State', "2018"]]
#state_and_2018 = state_and_2018.set_index("State")
#state_and_2018.head()

#q2_csv_df.plot(kind='bar', figsize=(20,8))
#plt.title("Wine Producers by State - U.S.")  
#plt.xlabel("States")
#plt.ylabel("Number of Producers")

#plt.show()
#plt.tight_layout()

# %%
x_axis = np.arange(0,len(producers_2018_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)


plt.title("Wine Producers by State - U.S.")  
plt.xlabel("States")
plt.ylabel("Number of Producers")

#plt.xlim(-0.75, len(q2_csv_df)-0.25)
#plt.ylim(ymax=500, ymin=1)

plt.figure(figsize=(20,8))
plt.bar(x_axis,producers_2018_df['2018'], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, producers_2018_df['State'], rotation='vertical')
# Out:
# <img src="data:image/png;base64,..." width="715.5555745113048">
# <img src="data:image/png;base64,..." width="1798.8889365431716">
# ([<matplotlib.axis.XTick at 0x138ee96fba8>,
#   <matplotlib.axis.XTick at 0x138ee96f4e0>,
#   <matplotlib.axis.XTick at 0x138ee96f390>,
#   <matplotlib.axis.XTick at 0x138e3de37f0>,
#   <matplotlib.axis.XTick at 0x138e3de3c88>,
#   <matplotlib.axis.XTick at 0x138e3e71198>,
#   <matplotlib.axis.XTick at 0x138e3e71668>,
#   <matplotlib.axis.XTick at 0x138e3e71b38>,
#   <matplotlib.axis.XTick at 0x138e3e550b8>,
#   <matplotlib.axis.XTick at 0x138e3e55518>,
#   <matplotlib.axis.XTick at 0x138e3e71710>,
#   <matplotlib.axis.XTick at 0x138e3de3908>,
#   <matplotlib.axis.XTick at 0x138e3e555f8>,
#   <matplotlib.axis.XTick at 0x138e3e55f28>,
#   <matplotlib.axis.XTick at 0x138e3e45438>,
#   <matplotlib.axis.XTick at 0x138e3e45908>,
#   <matplotlib.axis.XTick at 0x138e3e45dd8>,
#   <matplotlib.axis.XTick at 0x138e3e692e8>,
#   <matplotlib.axis.XTick at 0x138e3e697b8>,
#   <matplotlib.axis.XTick at 0x138e3e69c88>,
#   <matplotlib.axis.XTick at 0x138e3e69d68>,
#   <matplotlib.axis.XTick at 0x138e3e45588>,
#   <matplotlib.axis.XTick at 0x138e3e556d8>,
#   <matplotlib.axis.XTick at 0x138e3e404a8>,
#   <matplotlib.axis.XTick at 0x138e3e40a20>,
#   <matplotlib.axis.XTick at 0x138e3e40e80>,
#   <matplotlib.axis.XTick at 0x138e3bf8550>,
#   <matplotlib.axis.XTick at 0x138e3bf8ac8>,
#   <matplotlib.axis.XTick at 0x138e3bfb0f0>,
#   <matplotlib.axis.XTick at 0x138e3bf84a8>,
#   <matplotlib.axis.XTick at 0x138e3e40550>,
#   <matplotlib.axis.XTick at 0x138e3bfb4a8>,
#   <matplotlib.axis.XTick at 0x138e3bfbb70>,
#   <matplotlib.axis.XTick at 0x138e3bd8160>,
#   <matplotlib.axis.XTick at 0x138e3bd86a0>,
#   <matplotlib.axis.XTick at 0x138e3bd8c18>,
#   <matplotlib.axis.XTick at 0x138e3bc81d0>,
#   <matplotlib.axis.XTick at 0x138e3bc8748>,
#   <matplotlib.axis.XTick at 0x138e3bc8cc0>,
#   <matplotlib.axis.XTick at 0x138e3bc8828>,
#   <matplotlib.axis.XTick at 0x138e3bd8a20>,
#   <matplotlib.axis.XTick at 0x138e3be21d0>,
#   <matplotlib.axis.XTick at 0x138e3be2710>,
#   <matplotlib.axis.XTick at 0x138e3be2c88>,
#   <matplotlib.axis.XTick at 0x138e3bcb240>,
#   <matplotlib.axis.XTick at 0x138e3bcb7b8>,
#   <matplotlib.axis.XTick at 0x138e3bcbd30>,
#   <matplotlib.axis.XTick at 0x138e3bd42e8>,
#   <matplotlib.axis.XTick at 0x138e3bcb2e8>,
#   <matplotlib.axis.XTick at 0x138e3be2518>,
#   <matplotlib.axis.XTick at 0x138e3bd4630>],
#  <a list of 51 Text xticklabel objects>)

# %%
#plt.rcdefaults()
#fig, ax = plt.subplots()

#x_pos = np.arange(len(prod_states))
#ax.barh(x_pos, producers_2018, align='center',
        #color='blue', ecolor='black')
#ax.set_xticks(x_pos)
#ax.set_xticklabels("States")
#ax.invert_yaxis()  # labels read top-to-bottom
#ax.set_ylabel("Number of Producers")
#ax.set_title("Wine Producers by State - U.S.")

#plt.show()

# %%
plt.show()
plt.savefig('wineproducers_us_bar.png')
