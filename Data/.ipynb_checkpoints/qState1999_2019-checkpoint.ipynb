# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
plt.rcdefaults()

# %%
q2_csv = "q2-bonded-wine-producers-by-state-1999-june-2019.csv"
q2_csv_df = pd.read_csv(q2_csv, encoding="latin")
q2_csv_df.tail()
# Out:
#    State   1999   2000   2001   2002   2003   2004   2005   2006   2007  ...  \
# 46    VT   10.0   10.0    8.0    8.0    8.0   10.0   10.0   15.0   17.0  ...
# 47    WA  163.0  182.0  231.0  268.0  325.0  376.0  454.0  527.0  578.0  ...
# 48    WI   20.0   24.0   26.0   27.0   29.0   35.0   40.0   41.0   48.0  ...
# 49    WV   13.0   15.0   16.0   16.0   16.0   17.0   18.0   19.0   19.0  ...
# 50    WY    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...
#
#     2011  2012   2013   2014   2015    2016  2017  2018  Through 3/31/2019  \
# 46    35    37   42.0   43.0   47.0    51.0    68    71                 76
# 47   804   849  915.0  989.0  985.0  1019.0  1091  1171               1202
# 48    88   103  113.0  131.0  138.0   139.0   149   168                182
# 49    24    26   29.0   30.0   30.0    32.0    37    37                 39
# 50     *     5    6.0    7.0    8.0     8.0     8     9                 10
#
#     Through 6/30/2019
# 46                 79
# 47               1218
# 48                186
# 49                 39
# 50                 10
#
# [5 rows x 23 columns]

# %%
producers_2018 = q2_csv_df['2018']
producers_2018.head()
# Out:
# 0      10
# 1      42
# 2      36
# 3     111
# 4    5217
# Name: 2018, dtype: int64

# %%
prod_states = q2_csv_df['State']
prod_states.head()
# Out:
# 0    AK
# 1    AL
# 2    AR
# 3    AZ
# 4    CA
# Name: State, dtype: object

# %%
#years = q2_csv_df.keys()
#columns =pd.DataFrame(years)
#columns.head()

# %%
producers_2018_df=pd.concat([prod_states, producers_2018], axis=1)
producers_2018_df.head()
#wine2018_df = producers_2018_df.astype({'States':'float64', '2018':'float64'})
#wine2018_df.head()
# Out:
#   State  2018
# 0    AK    10
# 1    AL    42
# 2    AR    36
# 3    AZ   111
# 4    CA  5217

# %%
#state_and_2018 = q2_csv_df[['State', "2018"]]
#state_and_2018 = state_and_2018.set_index("State")
#state_and_2018.head()

#q2_csv_df.plot(kind='bar', figsize=(20,8))
#plt.title("Wine Producers by State - U.S.")  
#plt.xlabel("States")
#plt.ylabel("Number of Producers")

#plt.show()
#plt.tight_layout()

# %%
x_axis = np.arange(0,len(producers_2018_df))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)


plt.title("Wine Producers by State - U.S.")  
plt.xlabel("States")
plt.ylabel("Number of Producers")

#plt.xlim(-0.75, len(q2_csv_df)-0.25)
plt.ylim(ymax=500, ymin=1)

plt.figure(figsize=(20,10))
plt.bar(x_axis,producers_2018_df['2018'], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, producers_2018_df['State'], rotation='vertical')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="1999.9999566511683">
# ([<matplotlib.axis.XTick at 0x138e3eea940>,
#   <matplotlib.axis.XTick at 0x138e3eea278>,
#   <matplotlib.axis.XTick at 0x138e3eea128>,
#   <matplotlib.axis.XTick at 0x138e3ce8588>,
#   <matplotlib.axis.XTick at 0x138e3ce8a58>,
#   <matplotlib.axis.XTick at 0x138e3ce8f28>,
#   <matplotlib.axis.XTick at 0x138e3ce89b0>,
#   <matplotlib.axis.XTick at 0x138e3cec518>,
#   <matplotlib.axis.XTick at 0x138e3cec9e8>,
#   <matplotlib.axis.XTick at 0x138e3ceceb8>,
#   <matplotlib.axis.XTick at 0x138e3cdb3c8>,
#   <matplotlib.axis.XTick at 0x138e3cdb898>,
#   <matplotlib.axis.XTick at 0x138e3cdbd68>,
#   <matplotlib.axis.XTick at 0x138e3cc3278>,
#   <matplotlib.axis.XTick at 0x138e3cc3748>,
#   <matplotlib.axis.XTick at 0x138e3cdb860>,
#   <matplotlib.axis.XTick at 0x138e3cecb38>,
#   <matplotlib.axis.XTick at 0x138e3cc3ac8>,
#   <matplotlib.axis.XTick at 0x138e3cc30f0>,
#   <matplotlib.axis.XTick at 0x138e3ce33c8>,
#   <matplotlib.axis.XTick at 0x138e3ce38d0>,
#   <matplotlib.axis.XTick at 0x138e3ce3e48>,
#   <matplotlib.axis.XTick at 0x138e3cfb400>,
#   <matplotlib.axis.XTick at 0x138e3cfb978>,
#   <matplotlib.axis.XTick at 0x138e3cfbef0>,
#   <matplotlib.axis.XTick at 0x138e3cfbfd0>,
#   <matplotlib.axis.XTick at 0x138e3ce3320>,
#   <matplotlib.axis.XTick at 0x138e3cfd0f0>,
#   <matplotlib.axis.XTick at 0x138e3cfd940>,
#   <matplotlib.axis.XTick at 0x138e3cfdeb8>,
#   <matplotlib.axis.XTick at 0x138ee5d8470>,
#   <matplotlib.axis.XTick at 0x138ee5d89e8>,
#   <matplotlib.axis.XTick at 0x138ee5d8f60>,
#   <matplotlib.axis.XTick at 0x138ee5c8518>,
#   <matplotlib.axis.XTick at 0x138ee5d83c8>,
#   <matplotlib.axis.XTick at 0x138e3cfd7b8>,
#   <matplotlib.axis.XTick at 0x138ee5c8cf8>,
#   <matplotlib.axis.XTick at 0x138ee5b40b8>,
#   <matplotlib.axis.XTick at 0x138ee5b45c0>,
#   <matplotlib.axis.XTick at 0x138ee5b4b38>,
#   <matplotlib.axis.XTick at 0x138ee5b2160>,
#   <matplotlib.axis.XTick at 0x138ee5b2668>,
#   <matplotlib.axis.XTick at 0x138ee5b2be0>,
#   <matplotlib.axis.XTick at 0x138ee5a7198>,
#   <matplotlib.axis.XTick at 0x138ee5b2a58>,
#   <matplotlib.axis.XTick at 0x138ee5c8e80>,
#   <matplotlib.axis.XTick at 0x138ee5a7630>,
#   <matplotlib.axis.XTick at 0x138ee5a7ba8>,
#   <matplotlib.axis.XTick at 0x138ee5c9198>,
#   <matplotlib.axis.XTick at 0x138ee5c96d8>,
#   <matplotlib.axis.XTick at 0x138ee5c9c50>],
#  <a list of 51 Text xticklabel objects>)

# %%
#plt.rcdefaults()
#fig, ax = plt.subplots()

#x_pos = np.arange(len(prod_states))
#ax.barh(x_pos, producers_2018, align='center',
        #color='blue', ecolor='black')
#ax.set_xticks(x_pos)
#ax.set_xticklabels("States")
#ax.invert_yaxis()  # labels read top-to-bottom
#ax.set_ylabel("Number of Producers")
#ax.set_title("Wine Producers by State - U.S.")

#plt.show()
